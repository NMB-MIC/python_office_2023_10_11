# %%
import pandas as pd
import xlwings as xw
import datetime


def sale_report(path,save_file):

    import datetime
    import pandas as pd
    import os

    today = datetime.date.today()
    year = today.year-1

    xlxs_file_lists = []

    for root,dirs,files in os.walk(path):
        for name in files:
            file_path = os.path.join(root,name)
            if file_path.split("\\")[-2] == str(year): #change filter
                xlxs_file_lists.append(file_path)
    xlxs_file_lists

    # %%
    df_lists = []

    for f in xlxs_file_lists:
        df = pd.read_excel(f)
        df_lists.append(df)
    df_lists

    # %%
    df_summary = pd.concat(df_lists)
    df_summary

    # %%
    pivot = pd.pivot_table(df_summary,index="transaction_date",columns="store",values="amount",aggfunc="sum")
    pivot

    # %%
    summary_monthly = pivot.resample("M").sum()
    summary_monthly

    # %%
    import matplotlib
    fig = summary_monthly.plot(kind="bar",figsize=(20,12),fontsize=26,title="monthly sale summary").get_figure()

    # %%
    import xlwings as xw

    import datetime
    now = datetime.datetime.now()
    date_file_name = f'{str(now.date())}_{str(now.time()).split(".")[0].replace(":","_")}'


    template = xw.Book(r"data\sale_template.xlsx")

    app = xw.apps.active
    sheet = template.sheets["summary"]
    sheet["A1"].value = summary_monthly

    pivot_page = template.sheets["pivot"]
    pivot_page["A1"].value = pivot

    #add picture
    sheet_report = template.sheets["report"]
    sheet_report["A1"].value = "Summary by month"
    sheet_report['A1'].font.size = 24
    sheet_report["A1"].api.Font.Bold = True
    plot= sheet_report.pictures.add(fig,top=sheet["A3"].top,left=sheet["A3"].left)
    plot.width = plot.width*0.8
    plot.height = plot.height*0.8

    template.save(save_file+".xlsx")
    template.close()
    app.kill()

def browse_files():
    global path

    file_name = filedialog.askdirectory()
    path = file_name     
    file_explorer_label.configure(text=path)

def save_as():
    global save_as_dir

    save_file = filedialog.asksaveasfilename(initialdir = "/",
                                          title = "save as a File",
                                          filetypes = (("excel files",
                                                        "*.xlsx*"),
                                                       ("all files",
                                                        "*.*")))

    save_as_dir = save_file
    save_as_label.configure(text=save_as_dir)

def create_report_button_clicked():
    """create prodution report"""
    try:
        global path,save_as_dir
        sale_report(path,save_as_dir)
        file_explorer_label.config(text="browse files")
        save_as_label.config(text="Save as")
        messagebox.showinfo("info","Done")
    except Exception as e:
        messagebox.showerror("Error!!",e)
    

import tkinter as tk
from tkinter import ttk 
from tkinter import filedialog
from tkinter import messagebox

#global variable
path = None
save_as_dir = None

# root window
window = tk.Tk()
window.title("sale report program")
window.geometry("640x120")
window.resizable(False,False)

# frame
frame = ttk.Frame(window)

# field options
options = {'padx':5,'pady':5}

# Browse label
file_explorer_label = ttk.Label(frame,text="Browse File",width = 85)
file_explorer_label.grid(column=0,row=0,**options)

# browse button
browse_button = ttk.Button(frame,text="browse files")
browse_button.grid(column=1,row=0,**options)
browse_button.configure(command=browse_files)

# save_as label
save_as_label = ttk.Label(frame,text="Save as",width = 85)
save_as_label.grid(column=0,row=1,**options)

# save as path button
save_as_label_button = ttk.Button(frame,text="file location")
save_as_label_button.grid(column=1,row=1,**options)
save_as_label_button.configure(command=save_as)
 
# create report button
create_report_button = ttk.Button(frame,text="CREATE!")
create_report_button.grid(columnspan=2,row=3,**options)
create_report_button.configure(command=create_report_button_clicked)

# add frame
frame.grid(pady=10,padx=10)

window.mainloop() #run

# %% [markdown]
# #### build

# %%
# !pyinstaller.exe --noconsole sale_report_tk.py
# Out:
# 2579 INFO: PyInstaller: 6.1.0
# 2581 INFO: Python: 3.12.0 (conda)
# 2718 INFO: Platform: Windows-10-10.0.18363-SP0
# 2720 INFO: wrote d:\My Documents\Desktop\python_office_11_OCT_2023\src\sale_report_tk.spec
# 2732 INFO: Extending PYTHONPATH with paths
# ['d:\\My Documents\\Desktop\\python_office_11_OCT_2023\\src']
# 4016 INFO: checking Analysis
# 4017 INFO: Building Analysis because Analysis-00.toc is non existent
# 4017 INFO: Initializing module dependency graph...
# 4020 INFO: Caching module graph hooks...
# 4091 INFO: Analyzing base_library.zip ...
# 9999 INFO: Loading module hook 'hook-heapq.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 10444 INFO: Loading module hook 'hook-encodings.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 17589 INFO: Loading module hook 'hook-pickle.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 22004 INFO: Caching module dependency graph...
# 22406 INFO: Running Analysis Analysis-00.toc
# 22406 INFO: Looking for Python shared library...
# 22418 INFO: Using Python shared library: d:\newenv\python312.dll
# 22419 INFO: Analyzing d:\My Documents\Desktop\python_office_11_OCT_2023\src\sale_report_tk.py
# 22435 INFO: Loading module hook 'hook-pandas.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 26076 INFO: Loading module hook 'hook-platform.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 26211 INFO: Loading module hook 'hook-sysconfig.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 26275 INFO: Loading module hook 'hook-numpy.py' from 'D:\\newenv\\Lib\\site-packages\\numpy\\_pyinstaller'...
# 26353 WARNING: Conda distribution 'numpy', dependency of 'numpy', was not found. If you installed this distribution with pip then you may ignore this warning.
# 27790 INFO: Loading module hook 'hook-difflib.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 28282 INFO: Loading module hook 'hook-multiprocessing.util.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 28951 INFO: Loading module hook 'hook-xml.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 32020 INFO: Loading module hook 'hook-psutil.py' from 'd:\\newenv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 35444 INFO: Loading module hook 'hook-pytz.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 36146 INFO: Loading module hook 'hook-pkg_resources.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 42002 INFO: Loading module hook 'hook-pandas.io.formats.style.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 47074 INFO: Loading module hook 'hook-IPython.py' from 'd:\\newenv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 52247 INFO: Loading module hook 'hook-xml.dom.domreg.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 52762 INFO: Loading module hook 'hook-matplotlib.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 53502 INFO: Loading module hook 'hook-packaging.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 53716 INFO: Processing pre-safe import module hook gi from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-gi.py'.
# 53985 INFO: Loading module hook 'hook-PIL.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 54192 INFO: Loading module hook 'hook-PIL.Image.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 56690 INFO: Loading module hook 'hook-PIL.ImageFilter.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 62178 INFO: Processing pre-safe import module hook six.moves from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-six.moves.py'.
# 65138 INFO: Loading module hook 'hook-matplotlib.backends.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 68022 INFO: Loading module hook 'hook-pygments.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 72392 INFO: Loading module hook 'hook-importlib_metadata.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 73654 INFO: Loading module hook 'hook-lib2to3.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 75024 INFO: Loading module hook 'hook-wcwidth.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 77881 INFO: Loading module hook 'hook-jedi.py' from 'd:\\newenv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 80676 INFO: Loading module hook 'hook-parso.py' from 'd:\\newenv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 84037 INFO: Loading module hook 'hook-sqlite3.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 86338 INFO: Loading module hook 'hook-zmq.py' from 'd:\\newenv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 88611 INFO: Loading module hook 'hook-platformdirs.py' from 'd:\\newenv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 92673 INFO: Loading module hook 'hook-pandas.plotting.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 94778 INFO: Loading module hook 'hook-openpyxl.py' from 'd:\\newenv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 95731 INFO: Loading module hook 'hook-xml.etree.cElementTree.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 102093 INFO: Loading module hook 'hook-pywintypes.py' from 'd:\\newenv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 102222 INFO: Loading module hook 'hook-pythoncom.py' from 'd:\\newenv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 102359 INFO: Processing pre-safe import module hook win32com from 'd:\\newenv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\pre_safe_import_module\\hook-win32com.py'.
# 102455 INFO: Loading module hook 'hook-win32com.py' from 'd:\\newenv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 104488 INFO: Processing module hooks...
# 104560 INFO: Loading module hook 'hook-matplotlib.backends.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 104561 INFO: Matplotlib backend selection method: automatic discovery of used backends
# 105355 INFO: Found configured default matplotlib backend: module://matplotlib_inline.backend_inline
# 105355 INFO: Selected matplotlib backends: ['module://matplotlib_inline.backend_inline']
# 106451 INFO: Loading module hook 'hook-PIL.SpiderImagePlugin.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 113145 INFO: Loading module hook 'hook-_tkinter.py' from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks'...
# 113147 INFO: checking Tree
# 113148 INFO: Building Tree because Tree-00.toc is non existent
# 113148 INFO: Building Tree Tree-00.toc
# 113247 INFO: checking Tree
# 113247 INFO: Building Tree because Tree-01.toc is non existent
# 113247 INFO: Building Tree Tree-01.toc
# 113257 INFO: checking Tree
# 113257 INFO: Building Tree because Tree-02.toc is non existent
# 113258 INFO: Building Tree Tree-02.toc
# 114756 INFO: Looking for ctypes DLLs
# 115086 INFO: Analyzing run-time hooks ...
# 115111 INFO: Including run-time hook 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_inspect.py'
# 115114 INFO: Including run-time hook 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth__tkinter.py'
# 115117 INFO: Including run-time hook 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_mplconfig.py'
# 115119 INFO: Processing pre-find module path hook _pyi_rth_utils from 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path\\hook-_pyi_rth_utils.py'.
# 115149 INFO: Including run-time hook 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgutil.py'
# 115159 INFO: Including run-time hook 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_multiprocessing.py'
# 115167 INFO: Including run-time hook 'd:\\newenv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_traitlets.py'
# 115169 INFO: Including run-time hook 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgres.py'
# 115183 INFO: Including run-time hook 'd:\\newenv\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_win32comgenpy.py'
# 115185 INFO: Including run-time hook 'd:\\newenv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pywintypes.py'
# 115186 INFO: Including run-time hook 'd:\\newenv\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pythoncom.py'
# 115644 INFO: Looking for dynamic libraries
# d:\newenv\Lib\site-packages\PyInstaller\building\build_main.py:194: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(package)
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 120724 INFO: Extra DLL search directories (AddDllDirectory): ['d:\\newenv\\Lib\\site-packages\\matplotlib.libs', 'd:\\newenv\\Lib\\site-packages\\numpy.libs', 'd:\\newenv\\Lib\\site-packages\\matplotlib.libs', 'd:\\newenv\\Lib\\site-packages\\pandas.libs']
# 120724 INFO: Extra DLL search directories (PATH): []
# 125161 INFO: Warnings written to d:\My Documents\Desktop\python_office_11_OCT_2023\src\build\sale_report_tk\warn-sale_report_tk.txt
# 125781 INFO: Graph cross-reference written to d:\My Documents\Desktop\python_office_11_OCT_2023\src\build\sale_report_tk\xref-sale_report_tk.html
# 126146 INFO: checking PYZ
# 126146 INFO: Building PYZ because PYZ-00.toc is non existent
# 126146 INFO: Building PYZ (ZlibArchive) d:\My Documents\Desktop\python_office_11_OCT_2023\src\build\sale_report_tk\PYZ-00.pyz
# 134746 INFO: Building PYZ (ZlibArchive) d:\My Documents\Desktop\python_office_11_OCT_2023\src\build\sale_report_tk\PYZ-00.pyz completed successfully.
# 134909 INFO: checking PKG
# 134909 INFO: Building PKG because PKG-00.toc is non existent
# 134910 INFO: Building PKG (CArchive) sale_report_tk.pkg
# 134978 INFO: Building PKG (CArchive) sale_report_tk.pkg completed successfully.
# 134981 INFO: Bootloader d:\newenv\Lib\site-packages\PyInstaller\bootloader\Windows-64bit-intel\runw.exe
# 134982 INFO: checking EXE
# 134982 INFO: Building EXE because EXE-00.toc is non existent
# 134982 INFO: Building EXE from EXE-00.toc
# 134982 INFO: Copying bootloader EXE to d:\My Documents\Desktop\python_office_11_OCT_2023\src\build\sale_report_tk\sale_report_tk.exe
# 135507 INFO: Copying icon to EXE
# 135526 INFO: Copying 0 resources to EXE
# 135526 INFO: Embedding manifest in EXE
# 135547 INFO: Appending PKG archive to EXE
# 135567 INFO: Fixing EXE headers
# 136999 INFO: Building EXE from EXE-00.toc completed successfully.
# 137261 INFO: checking COLLECT
# 137262 INFO: Building COLLECT because COLLECT-00.toc is non existent
# 137262 INFO: Building COLLECT COLLECT-00.toc
# 164456 INFO: Building COLLECT COLLECT-00.toc completed successfully.
